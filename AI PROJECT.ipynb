# %%
<!DOCTYPE html>
<html lang="en">
<head>
<meta charset="UTF-8">
<meta name="viewport" content="width=device-width, initial-scale=1.0">
<title>GURUKULAi — Smart Learning Platform</title>
<link href="https://fonts.googleapis.com/css2?family=Playfair+Display:wght@700;800;900&family=Plus+Jakarta+Sans:wght@300;400;500;600;700&display=swap" rel="stylesheet">
<style>
:root {
  --bg:#07080f;--surface:#0e0f1a;--surface2:#161728;
  --border:rgba(255,255,255,0.07);--text:#eeeef5;--muted:#666780;
  --s-color:#34d9c3;--s-dim:rgba(52,217,195,0.1);
  --t-color:#ff9f43;--t-dim:rgba(255,159,67,0.1);
  --danger:#ff5470;--warn:#ffd166;--success:#06d6a0;
}
*{margin:0;padding:0;box-sizing:border-box;}
html{scroll-behavior:smooth;}
body{font-family:'Plus Jakarta Sans',sans-serif;background:var(--bg);color:var(--text);min-height:100vh;overflow-x:hidden;}
.screen{display:none;min-height:100vh;animation:fadeUp .35s ease;}
.screen.show{display:flex;}
@keyframes fadeUp{from{opacity:0;transform:translateY(14px)}to{opacity:1;transform:translateY(0)}}
#screen-landing{flex-direction:column;align-items:center;justify-content:center;background:radial-gradient(ellipse 70% 60% at 50% 0%,rgba(52,217,195,0.07) 0%,transparent 70%),radial-gradient(ellipse 50% 40% at 80% 100%,rgba(255,159,67,0.06) 0%,transparent 60%),var(--bg);text-align:center;padding:40px 20px;}
.brand-logo{font-family:'Playfair Display',serif;font-size:clamp(36px,6vw,64px);font-weight:900;letter-spacing:-1px;line-height:1;background:linear-gradient(135deg,#34d9c3 0%,#a78bfa 50%,#ff9f43 100%);-webkit-background-clip:text;-webkit-text-fill-color:transparent;background-clip:text;margin-bottom:10px;}
.brand-tag{font-size:14px;color:var(--muted);letter-spacing:3px;text-transform:uppercase;margin-bottom:50px;font-weight:500;}
.role-select-grid{display:grid;grid-template-columns:1fr 1fr;gap:20px;width:100%;max-width:560px;}
.role-card{background:var(--surface);border:1px solid var(--border);border-radius:20px;padding:36px 28px;cursor:pointer;transition:all .25s;display:flex;flex-direction:column;align-items:center;gap:14px;text-decoration:none;color:var(--text);}
.role-card:hover{transform:translateY(-4px);box-shadow:0 20px 40px rgba(0,0,0,.4);}
.role-card.student:hover{border-color:rgba(52,217,195,.4);background:rgba(52,217,195,.04);}
.role-card.teacher:hover{border-color:rgba(255,159,67,.4);background:rgba(255,159,67,.04);}
.role-icon{font-size:40px;}.role-name{font-family:'Playfair Display',serif;font-size:22px;font-weight:700;letter-spacing:-0.3px;}
.role-desc{font-size:12px;color:var(--muted);text-align:center;line-height:1.6;}
.role-card.student .role-name{color:var(--s-color);}.role-card.teacher .role-name{color:var(--t-color);}
.landing-footer{margin-top:50px;font-size:12px;color:var(--muted);}
.landing-footer span{background:linear-gradient(90deg,#34d9c3,#ff9f43);-webkit-background-clip:text;-webkit-text-fill-color:transparent;font-weight:700;}
#screen-login-student,#screen-login-teacher{flex-direction:row;min-height:100vh;}
.login-left{flex:1;display:flex;flex-direction:column;justify-content:center;align-items:flex-start;padding:60px;position:relative;overflow:hidden;}
.login-left::before{content:'';position:absolute;inset:0;background:radial-gradient(ellipse 80% 80% at 30% 50%,var(--glow-color) 0%,transparent 70%);pointer-events:none;}
.login-left.s{--glow-color:rgba(52,217,195,0.08);background:var(--surface);border-right:1px solid var(--border);}
.login-left.t{--glow-color:rgba(255,159,67,0.08);background:var(--surface);border-right:1px solid var(--border);}
.login-left-logo{font-family:'Playfair Display',serif;font-size:42px;font-weight:900;letter-spacing:-1px;margin-bottom:6px;}
.login-left-logo.s{color:var(--s-color);}.login-left-logo.t{color:var(--t-color);}
.login-left-sub{font-size:13px;color:var(--muted);letter-spacing:2px;text-transform:uppercase;margin-bottom:50px;}
.login-left h2{font-size:32px;font-weight:700;line-height:1.2;margin-bottom:14px;max-width:360px;}
.login-left p{font-size:14px;color:var(--muted);line-height:1.8;max-width:340px;}
.feature-list{margin-top:32px;display:flex;flex-direction:column;gap:12px;}
.feat{display:flex;align-items:center;gap:10px;font-size:13px;}
.feat-dot{width:7px;height:7px;border-radius:50%;flex-shrink:0;}
.feat-dot.s{background:var(--s-color);}.feat-dot.t{background:var(--t-color);}
.login-right{width:460px;display:flex;flex-direction:column;justify-content:center;align-items:center;padding:60px 48px;background:var(--bg);}
.login-box{width:100%;}
.login-back{background:none;border:none;color:var(--muted);font-family:'Plus Jakarta Sans';font-size:13px;cursor:pointer;display:flex;align-items:center;gap:6px;padding:0;margin-bottom:40px;transition:color .2s;}
.login-back:hover{color:var(--text);}
.login-title{font-family:'Playfair Display',serif;font-size:28px;font-weight:800;margin-bottom:6px;}
.login-subtitle{font-size:13px;color:var(--muted);margin-bottom:32px;}
.form-group{margin-bottom:18px;}
.form-label{font-size:12px;font-weight:600;color:var(--muted);letter-spacing:.5px;text-transform:uppercase;margin-bottom:7px;display:block;}
.form-input{width:100%;background:var(--surface);border:1px solid var(--border);border-radius:12px;padding:13px 16px;color:var(--text);font-family:'Plus Jakarta Sans';font-size:14px;transition:border-color .2s;}
.form-input:focus{outline:none;}
.form-input.s:focus{border-color:rgba(52,217,195,.4);}.form-input.t:focus{border-color:rgba(255,159,67,.4);}
.login-btn{width:100%;padding:14px;border-radius:12px;border:none;font-family:'Plus Jakarta Sans';font-size:15px;font-weight:700;cursor:pointer;transition:all .2s;margin-top:8px;}
.login-btn.s{background:var(--s-color);color:#000;}.login-btn.t{background:var(--t-color);color:#000;}
.login-btn:hover{opacity:.88;transform:translateY(-1px);}
.login-demo{margin-top:20px;text-align:center;font-size:12px;color:var(--muted);}
.demo-fill{color:var(--s-color);cursor:pointer;font-weight:600;}.demo-fill.t{color:var(--t-color);}
#screen-student-dash,#screen-teacher-dash{flex-direction:column;}
.topbar{display:flex;align-items:center;justify-content:space-between;padding:0 32px;height:58px;background:var(--surface);border-bottom:1px solid var(--border);position:sticky;top:0;z-index:100;}
.topbar-logo{font-family:'Playfair Display',serif;font-weight:900;font-size:20px;letter-spacing:-.3px;}
.topbar-logo.s{color:var(--s-color);}.topbar-logo.t{color:var(--t-color);}
.topbar-center{font-size:13px;color:var(--muted);}
.topbar-right{display:flex;align-items:center;gap:12px;}
.avatar{width:34px;height:34px;border-radius:50%;display:flex;align-items:center;justify-content:center;font-size:12px;font-weight:700;}
.av-s{background:var(--s-dim);color:var(--s-color);}.av-t{background:var(--t-dim);color:var(--t-color);}
.logout-btn{background:var(--surface2);border:1px solid var(--border);color:var(--muted);font-family:'Plus Jakarta Sans';font-size:12px;padding:6px 14px;border-radius:8px;cursor:pointer;transition:all .2s;}
.logout-btn:hover{color:var(--text);border-color:rgba(255,255,255,.15);}
.dash-body{padding:28px 32px;max-width:1360px;margin:0 auto;width:100%;}
@media(max-width:700px){.dash-body{padding:16px;}}
.page-hd{display:flex;justify-content:space-between;align-items:flex-start;margin-bottom:26px;flex-wrap:wrap;gap:12px;}
.page-hd h1{font-family:'Playfair Display',serif;font-size:26px;font-weight:800;letter-spacing:-.3px;}
.page-hd p{font-size:13px;color:var(--muted);margin-top:4px;}
.g3{display:grid;grid-template-columns:repeat(3,1fr);gap:16px;margin-bottom:18px;}
.g2{display:grid;grid-template-columns:repeat(2,1fr);gap:16px;margin-bottom:18px;}
.g4{display:grid;grid-template-columns:repeat(4,1fr);gap:16px;margin-bottom:18px;}
@media(max-width:1000px){.g3,.g4{grid-template-columns:1fr 1fr;}}
@media(max-width:650px){.g3,.g4,.g2{grid-template-columns:1fr;}}
.card{background:var(--surface);border:1px solid var(--border);border-radius:16px;padding:20px;}
.card-hd{display:flex;justify-content:space-between;align-items:center;margin-bottom:16px;}
.card-title{font-size:13px;font-weight:700;letter-spacing:.2px;}
.badge{padding:3px 10px;border-radius:20px;font-size:11px;font-weight:700;}
.bs{background:var(--s-dim);color:var(--s-color);}.bt{background:var(--t-dim);color:var(--t-color);}
.bw{background:rgba(255,209,102,.15);color:var(--warn);}.bd{background:rgba(255,84,112,.12);color:var(--danger);}
.bk{background:rgba(6,214,160,.12);color:var(--success);}
.qs-row{display:grid;grid-template-columns:repeat(4,1fr);gap:14px;margin-bottom:18px;}
@media(max-width:800px){.qs-row{grid-template-columns:1fr 1fr;}}
.qs{background:var(--surface);border:1px solid var(--border);border-radius:14px;padding:16px 18px;}
.qs-lbl{font-size:11px;color:var(--muted);text-transform:uppercase;letter-spacing:.5px;margin-bottom:6px;}
.qs-val{font-family:'Playfair Display',serif;font-size:30px;font-weight:800;line-height:1;}
.qs-sub{font-size:11px;color:var(--muted);margin-top:5px;}
.up{color:var(--success);}
.pbar{height:6px;border-radius:3px;background:var(--surface2);overflow:hidden;}
.pfill{height:100%;border-radius:3px;}
.rep-row{display:flex;align-items:center;gap:10px;margin-bottom:11px;}
.rep-row:last-child{margin-bottom:0;}
.rep-name{font-size:12px;width:80px;flex-shrink:0;}
.rep-pct{font-size:12px;font-weight:700;width:32px;text-align:right;flex-shrink:0;}
.btn{padding:9px 18px;border-radius:10px;border:none;font-family:'Plus Jakarta Sans';font-size:13px;font-weight:600;cursor:pointer;transition:all .2s;display:inline-flex;align-items:center;gap:6px;}
.btn-s{background:var(--s-color);color:#000;}.btn-t{background:var(--t-color);color:#000;}
.btn-g{background:var(--surface2);color:var(--text);border:1px solid var(--border);}
.btn:hover{opacity:.85;transform:translateY(-1px);}.btn:active{transform:translateY(0);}
.pomo-wrap{text-align:center;}
.pomo-sub-tabs{display:flex;gap:7px;flex-wrap:wrap;margin-bottom:14px;justify-content:center;}
.pomo-tab{padding:6px 13px;border-radius:20px;border:1px solid var(--border);background:transparent;color:var(--muted);font-family:'Plus Jakarta Sans';font-size:12px;font-weight:600;cursor:pointer;transition:all .2s;}
.pomo-tab.active{background:var(--s-dim);color:var(--s-color);border-color:rgba(52,217,195,.3);}
.pomo-ring{position:relative;width:140px;height:140px;margin:0 auto 14px;}
.pomo-ring svg{transform:rotate(-90deg);}
.pomo-ring-bg{fill:none;stroke:var(--surface2);stroke-width:8;}
.pomo-ring-fg{fill:none;stroke:var(--s-color);stroke-width:8;stroke-linecap:round;transition:stroke-dashoffset .5s linear;}
.pomo-center{position:absolute;top:50%;left:50%;transform:translate(-50%,-50%);text-align:center;}
.pomo-time{font-family:'Playfair Display',serif;font-size:30px;font-weight:900;color:var(--s-color);line-height:1;}
.pomo-session{font-size:10px;color:var(--muted);margin-top:3px;}
.pomo-btns{display:flex;gap:8px;justify-content:center;margin-top:4px;}
.flashcard{perspective:900px;height:130px;cursor:pointer;margin-bottom:12px;}
.fc-inner{position:relative;width:100%;height:100%;transform-style:preserve-3d;transition:transform .5s;}
.flashcard.flipped .fc-inner{transform:rotateY(180deg);}
.fc-f,.fc-b{position:absolute;width:100%;height:100%;backface-visibility:hidden;border-radius:12px;display:flex;flex-direction:column;align-items:center;justify-content:center;padding:16px;gap:6px;text-align:center;}
.fc-f{background:var(--s-dim);border:1px solid rgba(52,217,195,.2);}
.fc-b{background:var(--surface2);border:1px solid var(--border);transform:rotateY(180deg);}
.fc-q{font-size:13px;font-weight:600;color:var(--s-color);}.fc-hint{font-size:10px;color:var(--muted);}.fc-ans{font-size:14px;font-weight:700;}
.fc-btns{display:flex;gap:8px;}.fc-btns .btn{flex:1;font-size:12px;padding:7px 10px;}
.lb-row{display:flex;align-items:center;gap:10px;padding:9px 0;border-bottom:1px solid rgba(255,255,255,.04);}
.lb-row:last-child{border-bottom:none;}
.lb-rank{font-family:'Playfair Display',serif;font-weight:800;font-size:15px;width:28px;color:var(--muted);}
.lb-rank.gd{color:#ffd700;}.lb-rank.sv{color:#c0c0c0;}.lb-rank.br{color:#cd7f32;}
.lb-me{background:var(--s-dim);border-radius:8px;padding:6px 10px;}
.lb-pts{font-family:'Playfair Display',serif;font-weight:800;font-size:13px;color:var(--s-color);}
.chat-area{height:190px;overflow-y:auto;display:flex;flex-direction:column;gap:10px;padding-right:4px;}
.chat-msg{display:flex;gap:8px;}.chat-msg.user{flex-direction:row-reverse;}
.bubble{max-width:80%;padding:10px 13px;border-radius:13px;font-size:12px;line-height:1.6;}
.chat-msg.ai .bubble{background:var(--surface2);border:1px solid var(--border);}
.chat-msg.user .bubble{background:var(--s-dim);border:1px solid rgba(52,217,195,.2);}
.bot-av{width:26px;height:26px;border-radius:50%;background:var(--s-dim);display:flex;align-items:center;justify-content:center;font-size:13px;flex-shrink:0;}
.chat-row{display:flex;gap:8px;margin-top:10px;}
.chat-inp{flex:1;background:var(--surface2);border:1px solid var(--border);border-radius:10px;padding:9px 13px;color:var(--text);font-family:'Plus Jakarta Sans';font-size:12px;}
.chat-inp:focus{outline:1px solid var(--s-color);}
table{width:100%;border-collapse:collapse;font-size:13px;}
th{color:var(--muted);font-weight:500;padding:9px 10px;text-align:left;border-bottom:1px solid var(--border);}
td{padding:10px 10px;border-bottom:1px solid rgba(255,255,255,.04);}
tr:last-child td{border-bottom:none;}tr:hover td{background:rgba(255,255,255,.015);}
input[type=number]{background:var(--surface2);border:1px solid var(--border);color:var(--text);padding:5px 7px;border-radius:6px;width:60px;font-family:'Plus Jakarta Sans';font-size:12px;}
input[type=number]:focus{outline:1px solid var(--t-color);}
.heatmap{display:grid;grid-template-columns:repeat(5,1fr);gap:6px;margin-bottom:0;}
.hmap{border-radius:8px;padding:8px 4px;text-align:center;cursor:pointer;transition:transform .2s;border:1px solid transparent;}
.hmap:hover{transform:scale(1.06);}
.hmap .hn{font-size:9px;color:rgba(255,255,255,.55);margin-bottom:3px;}
.hmap .hv{font-family:'Playfair Display',serif;font-size:17px;font-weight:800;}
.hstr{background:rgba(6,214,160,.2);border-color:rgba(6,214,160,.3);color:var(--success);}
.havg{background:rgba(255,209,102,.15);border-color:rgba(255,209,102,.25);color:var(--warn);}
.hwk{background:rgba(255,84,112,.15);border-color:rgba(255,84,112,.25);color:var(--danger);}
.sms-target{display:flex;gap:7px;flex-wrap:wrap;margin-bottom:12px;}
.stag{padding:5px 12px;border-radius:20px;font-size:11px;font-weight:600;border:1px solid var(--border);background:transparent;color:var(--muted);cursor:pointer;transition:all .2s;}
.stag.on{background:var(--t-dim);color:var(--t-color);border-color:rgba(255,159,67,.3);}
.sms-box{width:100%;background:var(--surface2);border:1px solid var(--border);border-radius:10px;padding:12px 14px;color:var(--text);font-family:'Plus Jakarta Sans';font-size:13px;resize:none;min-height:80px;}
.sms-box:focus{outline:1px solid var(--t-color);}
.sms-preview{background:linear-gradient(135deg,rgba(255,159,67,.07),rgba(255,159,67,.03));border:1px solid rgba(255,159,67,.2);border-radius:10px;padding:12px 14px;font-size:12px;line-height:1.7;margin-top:10px;display:none;}
.sms-preview strong{color:var(--t-color);}
.lang-sel{background:var(--surface2);border:1px solid var(--border);color:var(--text);padding:7px 10px;border-radius:8px;font-family:'Plus Jakarta Sans';font-size:12px;cursor:pointer;}
.cl-row{display:flex;align-items:center;gap:8px;padding:8px 0;border-bottom:1px solid rgba(255,255,255,.04);}
.cl-row:last-child{border-bottom:none;}
.cl-name{flex:1;font-size:13px;}.chip{padding:3px 10px;border-radius:20px;font-size:11px;font-weight:700;}
.cstr{background:rgba(6,214,160,.15);color:var(--success);}.cavg{background:rgba(255,209,102,.15);color:var(--warn);}.cwk{background:rgba(255,84,112,.12);color:var(--danger);}
.cl-avg-val{font-size:11px;color:var(--muted);}
.gk-opt{width:100%;text-align:left;background:var(--surface2);border:1px solid var(--border);color:var(--text);padding:9px 14px;border-radius:9px;margin-bottom:7px;font-family:'Plus Jakarta Sans';font-size:13px;cursor:pointer;transition:all .2s;}
.gk-opt:hover{border-color:rgba(52,217,195,.3);background:var(--s-dim);}
.gk-opt:last-child{margin-bottom:0;}.gk-opt:disabled{cursor:default;}
.modal-overlay{position:fixed;inset:0;background:rgba(0,0,0,.75);z-index:999;display:none;align-items:center;justify-content:center;backdrop-filter:blur(4px);}
.modal-overlay.show{display:flex;animation:fadeUp .3s ease;}
.modal-box{background:var(--surface);border:1px solid rgba(52,217,195,.25);border-radius:20px;padding:36px 32px;max-width:380px;width:90%;text-align:center;}
.modal-emoji{font-size:48px;margin-bottom:16px;}
.modal-title{font-family:'Playfair Display',serif;font-size:22px;font-weight:800;margin-bottom:10px;color:var(--s-color);}
.modal-msg{font-size:14px;color:var(--muted);line-height:1.7;margin-bottom:24px;}
.modal-sub{font-size:13px;color:var(--text);margin-bottom:20px;font-weight:500;}
::-webkit-scrollbar{width:4px;}::-webkit-scrollbar-track{background:transparent;}::-webkit-scrollbar-thumb{background:var(--surface2);border-radius:2px;}
.section-lbl{font-size:11px;font-weight:700;letter-spacing:1px;text-transform:uppercase;color:var(--muted);margin-bottom:12px;}
.bar-chart{display:flex;align-items:flex-end;gap:8px;height:90px;}
.bc{display:flex;flex-direction:column;align-items:center;gap:5px;flex:1;}
.bar{width:100%;border-radius:6px 6px 0 0;}.bl{font-size:10px;color:var(--muted);}.bv{font-size:10px;font-weight:700;}
.study-topic-grid{display:grid;grid-template-columns:repeat(2,1fr);gap:10px;margin-bottom:16px;}
@media(max-width:600px){.study-topic-grid{grid-template-columns:1fr;}}
.study-topic-card{background:var(--surface2);border:1px solid var(--border);border-radius:12px;padding:14px;cursor:pointer;transition:all .2s;}
.study-topic-card:hover{border-color:rgba(52,217,195,.35);transform:translateY(-2px);}
.study-topic-card.active{border-color:var(--s-color);background:var(--s-dim);}
.stc-icon{font-size:22px;margin-bottom:6px;}
.stc-title{font-size:13px;font-weight:700;color:var(--text);margin-bottom:3px;}
.stc-desc{font-size:11px;color:var(--muted);}
.study-content-box{background:var(--surface2);border:1px solid var(--border);border-radius:12px;padding:18px;display:none;}
.study-content-box.show{display:block;animation:fadeUp .3s ease;}
.study-content-header{display:flex;justify-content:space-between;align-items:center;margin-bottom:14px;}
.study-content-title{font-family:'Playfair Display',serif;font-size:18px;font-weight:800;color:var(--s-color);}
.study-section{margin-bottom:16px;}
.study-section-label{font-size:11px;font-weight:700;letter-spacing:1px;text-transform:uppercase;color:var(--muted);margin-bottom:8px;display:flex;align-items:center;gap:6px;}
.study-section-label::after{content:'';flex:1;height:1px;background:var(--border);}
.study-point{display:flex;gap:10px;margin-bottom:8px;font-size:13px;line-height:1.6;}
.study-point-dot{width:6px;height:6px;border-radius:50%;background:var(--s-color);flex-shrink:0;margin-top:7px;}
.formula-box{background:rgba(52,217,195,.06);border:1px solid rgba(52,217,195,.2);border-radius:8px;padding:10px 14px;font-size:13px;font-family:monospace;margin-bottom:8px;color:var(--s-color);font-weight:600;}
.tip-box{background:rgba(255,209,102,.07);border:1px solid rgba(255,209,102,.2);border-radius:8px;padding:10px 14px;font-size:12px;line-height:1.7;color:var(--warn);}
.quiz-q{background:var(--surface);border:1px solid var(--border);border-radius:10px;padding:14px;margin-bottom:10px;}
.quiz-q-text{font-size:13px;font-weight:600;margin-bottom:10px;}
.quiz-opts{display:flex;flex-direction:column;gap:6px;}
.quiz-opt{background:var(--surface2);border:1px solid var(--border);border-radius:7px;padding:8px 12px;font-size:12px;cursor:pointer;transition:all .2s;text-align:left;}
.quiz-opt:hover{border-color:rgba(52,217,195,.3);background:var(--s-dim);}
.quiz-opt:disabled{cursor:default;}
.quiz-opt.correct{background:rgba(6,214,160,.15)!important;border-color:var(--success)!important;color:var(--success);font-weight:700;}
.quiz-opt.wrong{background:rgba(255,84,112,.1)!important;border-color:var(--danger)!important;color:var(--danger);}
.study-loading{text-align:center;padding:30px;color:var(--muted);font-size:13px;}
.study-loading .spin{display:inline-block;font-size:24px;animation:spin 1s linear infinite;margin-bottom:10px;}
@keyframes spin{from{transform:rotate(0deg)}to{transform:rotate(360deg)}}
.pomo-sync-note{font-size:11px;color:var(--s-color);background:var(--s-dim);border-radius:8px;padding:6px 12px;display:inline-flex;align-items:center;gap:6px;}
</style>
</head>
<body>
<div class="screen show" id="screen-landing">
  <div class="brand-logo">GURUKULAi</div>
  <div class="brand-tag">AI-Powered Learning Platform</div>
  <div class="role-select-grid">
    <div class="role-card student" onclick="goLogin('student')">
      <div class="role-icon">🎓</div><div class="role-name">Student</div>
      <div class="role-desc">Study smarter with AI flashcards, doubt buddy, Pomodoro & leaderboards</div>
    </div>
    <div class="role-card teacher" onclick="goLogin('teacher')">
      <div class="role-icon">👩‍🏫</div><div class="role-name">Teacher</div>
      <div class="role-desc">Manage marks, analyse class performance & send SMS updates to parents</div>
    </div>
  </div>
  <div class="landing-footer">Powered by <span>Azure Cloud Services</span> · Built for Bharat 🇮🇳</div>
</div>
<div class="screen" id="screen-login-student">
  <div class="login-left s">
    <div class="login-left-logo s">GURUKULAi</div><div class="login-left-sub">Student Portal</div>
    <h2>Learn Smarter,<br>Score Better.</h2>
    <p>Your personalised AI learning companion — doubts, flashcards, quizzes and a Pomodoro planner, all in one place.</p>
    <div class="feature-list">
      <div class="feat"><div class="feat-dot s"></div>AI Doubt Buddy with regional language support</div>
      <div class="feat"><div class="feat-dot s"></div>Pomodoro Study Planner with AI motivation</div>
      <div class="feat"><div class="feat-dot s"></div>Daily GK Quiz & live class leaderboard</div>
      <div class="feat"><div class="feat-dot s"></div>📚 AI Study Material — synced with Pomodoro subject</div>
    </div>
  </div>
  <div class="login-right"><div class="login-box">
    <button class="login-back" onclick="goScreen('screen-landing')">← Back to home</button>
    <div class="login-title">Student Login</div>
    <div class="login-subtitle">Enter your school credentials to continue</div>
    <div class="form-group"><label class="form-label">Student ID / Roll No.</label><input class="form-input s" type="text" id="s-id" placeholder="e.g. STU2026001"></div>
    <div class="form-group"><label class="form-label">Password</label><input class="form-input s" type="password" id="s-pw" placeholder="••••••••"></div>
    <div class="form-group"><label class="form-label">Class / Section</label>
      <select class="form-input s" style="cursor:pointer"><option>Class X — Section A</option><option>Class X — Section B</option><option>Class XI — Section A</option><option>Class XII — Section A</option></select>
    </div>
    <button class="login-btn s" onclick="loginStudent()">Continue to Dashboard →</button>
    <div class="login-demo">Demo: <span class="demo-fill" onclick="fillStudentDemo()">Click to fill demo credentials</span></div>
  </div></div>
</div>
<div class="screen" id="screen-login-teacher">
  <div class="login-left t">
    <div class="login-left-logo t">GURUKULAi</div><div class="login-left-sub">Teacher Portal</div>
    <h2>Understand Every<br>Student. Instantly.</h2>
    <p>AI-powered class analytics, marks input, automated weak-student alerts and direct SMS to parents.</p>
    <div class="feature-list">
      <div class="feat"><div class="feat-dot t"></div>Auto-classify students as Weak / Average / Strong</div>
      <div class="feat"><div class="feat-dot t"></div>Subject performance heatmap at a glance</div>
      <div class="feat"><div class="feat-dot t"></div>Send multilingual SMS to parents via Azure</div>
      <div class="feat"><div class="feat-dot t"></div>Attendance tracking with auto alerts</div>
    </div>
  </div>
  <div class="login-right"><div class="login-box">
    <button class="login-back" onclick="goScreen('screen-landing')">← Back to home</button>
    <div class="login-title">Teacher Login</div>
    <div class="login-subtitle">Enter your faculty credentials to continue</div>
    <div class="form-group"><label class="form-label">Teacher ID</label><input class="form-input t" type="text" id="t-id" placeholder="e.g. TCH20260014"></div>
    <div class="form-group"><label class="form-label">Password</label><input class="form-input t" type="password" id="t-pw" placeholder="••••••••"></div>
    <div class="form-group"><label class="form-label">Department</label>
      <select class="form-input t" style="cursor:pointer"><option>Mathematics</option><option>Science (Physics / Chemistry)</option><option>Biology</option><option>Languages</option><option>Social Studies</option></select>
    </div>
    <button class="login-btn t" onclick="loginTeacher()">Continue to Dashboard →</button>
    <div class="login-demo">Demo: <span class="demo-fill t" onclick="fillTeacherDemo()">Click to fill demo credentials</span></div>
  </div></div>
</div>

<div class="screen" id="screen-student-dash">
  <nav class="topbar">
    <div class="topbar-logo s">GURUKULAi</div>
    <div class="topbar-center">🎓 Student Dashboard — Class X-A</div>
    <div class="topbar-right">
      <div class="avatar av-s">AR</div>
      <span style="font-size:13px;font-weight:600">Arjun Rao</span>
      <button class="logout-btn" onclick="goScreen('screen-landing')">Logout</button>
    </div>
  </nav>
  <div class="dash-body">
    <div class="page-hd">
      <div><h1>Good morning, <span style="color:var(--s-color)">Arjun! 👋</span></h1><p>3 flashcards pending · Today's GK question is live · Streak: 🔥 12 days</p></div>
      <button class="btn btn-s" onclick="openDoubt()">💬 AI Doubt Buddy</button>
    </div>
    <div class="qs-row">
      <div class="qs"><div class="qs-lbl">Overall Score</div><div class="qs-val" style="color:var(--s-color)">78%</div><div class="qs-sub up">↑ +6% this week</div></div>
      <div class="qs"><div class="qs-lbl">Study Streak</div><div class="qs-val" style="color:var(--warn)">🔥12</div><div class="qs-sub">days in a row</div></div>
      <div class="qs"><div class="qs-lbl">Leaderboard</div><div class="qs-val" style="color:#a78bfa">#4</div><div class="qs-sub">Top 15% of class</div></div>
      <div class="qs"><div class="qs-lbl">Weak Subject</div><div class="qs-val" style="color:var(--danger);font-size:17px;margin-top:6px">Chemistry</div><div class="qs-sub">AI plan active</div></div>
    </div>
    <div class="g3">
      <div class="card">
        <div class="card-hd"><span class="card-title">How are you feeling today?</span><span class="badge bs">AI Aware</span></div>
        <p style="font-size:12px;color:var(--muted);margin-bottom:12px">AI adjusts question difficulty based on your mood</p>
        <div style="display:flex;gap:8px;justify-content:center;margin-bottom:12px">
          <button class="btn btn-g" style="font-size:20px;padding:8px 12px" onclick="setMood(this,'Easy warm-up mode activated 😴')">😴</button>
          <button class="btn btn-g" style="font-size:20px;padding:8px 12px" onclick="setMood(this,'Standard difficulty today 📚')">😐</button>
          <button class="btn btn-s" style="font-size:20px;padding:8px 12px" onclick="setMood(this,'Medium-hard questions today 🎯')">😊</button>
          <button class="btn btn-g" style="font-size:20px;padding:8px 12px" onclick="setMood(this,'CHALLENGE MODE ON 🔥')">🤩</button>
        </div>
        <div id="mood-out" style="font-size:12px;color:var(--s-color);text-align:center;font-weight:600">Medium-hard questions today 🎯</div>
      </div>
      <div class="card">
        <div class="card-hd"><span class="card-title">🍅 Pomodoro Study Timer</span><span class="badge bs" id="pomo-session-badge">Session 1 of 4</span></div>
        <div class="pomo-wrap">
          <div class="pomo-sub-tabs">
            <button class="pomo-tab active" onclick="switchPomoSub(this,'Maths')">Maths</button>
            <button class="pomo-tab" onclick="switchPomoSub(this,'Physics')">Physics</button>
            <button class="pomo-tab" onclick="switchPomoSub(this,'Chemistry')">Chemistry</button>
          </div>
          <div class="pomo-ring">
            <svg viewBox="0 0 140 140" width="140" height="140">
              <circle class="pomo-ring-bg" cx="70" cy="70" r="58"/>
              <circle class="pomo-ring-fg" id="pomo-ring" cx="70" cy="70" r="58" stroke-dasharray="364.4" stroke-dashoffset="0"/>
            </svg>
            <div class="pomo-center">
              <div class="pomo-time" id="pomo-display">25:00</div>
              <div class="pomo-session" id="pomo-sub-label">Maths</div>
            </div>
          </div>
          <div class="pomo-btns">
            <button class="btn btn-s" id="pomo-start-btn" onclick="togglePomo()">▶ Start</button>
            <button class="btn btn-g" onclick="resetPomo()">↺ Reset</button>
          </div>
          <div style="font-size:11px;color:var(--muted);margin-top:8px">📚 Study material auto-loads on subject switch</div>
        </div>
      </div>
      <div class="card">
        <div class="card-hd"><span class="card-title">🧠 Interactive Quiz</span><span class="badge bw" id="quiz-badge">+5 pts per correct</span></div>
        <div id="quiz-container">
          <p style="font-size:13px;font-weight:600;margin-bottom:12px" id="quiz-question">Loading quiz...</p>
          <div id="quiz-options"></div>
          <div id="quiz-result" style="display:none;margin-top:10px;font-size:12px;font-weight:600"></div>
          <div style="display:flex;gap:8px;margin-top:10px">
            <button class="btn btn-s" id="next-quiz-btn" onclick="loadNextQuiz()" style="display:none">Next Question</button>
            <button class="btn btn-g" onclick="loadRandomQuiz()">🔄 New Quiz</button>
          </div>
        </div>
      </div>
    </div>
    <div class="card" style="margin-bottom:18px">
      <div class="card-hd">
        <span class="card-title">📚 AI Study Material</span>
        <span class="pomo-sync-note">🔗 Synced with Pomodoro · Subject: <strong id="study-sync-label">Maths</strong></span>
      </div>
      <div class="pomo-sub-tabs" style="justify-content:flex-start;margin-bottom:16px" id="study-tabs">
        <button class="pomo-tab active" onclick="loadStudyMaterial(this,'Maths')">📐 Maths</button>
        <button class="pomo-tab" onclick="loadStudyMaterial(this,'Physics')">⚛ Physics</button>
        <button class="pomo-tab" onclick="loadStudyMaterial(this,'Chemistry')">🧪 Chemistry</button>
        <button class="pomo-tab" onclick="loadStudyMaterial(this,'Biology')">🌿 Biology</button>
        <button class="pomo-tab" onclick="loadStudyMaterial(this,'History')">📜 History</button>
      </div>
      <div id="study-topic-grid" class="study-topic-grid"></div>
      <div class="study-content-box" id="study-content-box">
        <div class="study-content-header">
          <div class="study-content-title" id="study-content-title">📐 Quadratic Equations</div>
          <div style="display:flex;gap:8px">
            <button class="btn btn-g" style="font-size:11px;padding:5px 12px" onclick="startTopicQuiz()">🧠 Take Quiz</button>
            <button class="btn btn-g" style="font-size:11px;padding:5px 12px" onclick="closeStudyContent()">← All Topics</button>
          </div>
        </div>
        <div id="study-content-body"></div>
      </div>
      <div class="study-loading" id="study-loading" style="display:none">
        <div class="spin">⚛️</div>
        <div>AI is preparing your study material...</div>
      </div>
    </div>
    <div class="g2">
      <div class="card">
        <div class="card-hd"><span class="card-title">🃏 AI Flashcards</span><span class="badge bs" id="fc-count">35 left today</span></div>
        <div class="flashcard" id="flashcard" onclick="flipFC()">
          <div class="fc-inner">
            <div class="fc-f"><div class="fc-q" id="fc-q">What is the atomic number of Carbon?</div><div class="fc-hint">👆 Tap to reveal answer</div></div>
            <div class="fc-b"><div style="font-size:22px">⚛️</div><div class="fc-ans" id="fc-a">6</div><div class="fc-hint" id="fc-hint">Carbon has 6 protons in its nucleus</div></div>
          </div>
        </div>
        <div class="fc-btns">
          <button class="btn btn-g" onclick="nextFC('hard')">😓 Hard</button>
          <button class="btn btn-g" onclick="nextFC('ok')">😐 OK</button>
          <button class="btn btn-s" onclick="nextFC('easy')">😊 Easy</button>
        </div>
        <p style="font-size:11px;color:var(--muted);margin-top:10px">35 questions · Auto-shuffled · Chemistry, Physics, Maths, Biology, GK</p>
      </div>
      <div class="card">
        <div class="card-hd"><span class="card-title">🏆 Class Leaderboard</span><span class="badge bw">Weekly</span></div>
        <div class="lb-row"><div class="lb-rank gd">🥇</div><span style="flex:1;font-size:13px">Sneha Reddy</span><div class="lb-pts">420 pts</div></div>
        <div class="lb-row"><div class="lb-rank sv">🥈</div><span style="flex:1;font-size:13px">Rahul Kumar</span><div class="lb-pts">385 pts</div></div>
        <div class="lb-row"><div class="lb-rank br">🥉</div><span style="flex:1;font-size:13px">Priya Sharma</span><div class="lb-pts">360 pts</div></div>
        <div class="lb-row lb-me"><div class="lb-rank" style="color:var(--s-color)">#4</div><span style="flex:1;font-size:13px;font-weight:700;color:var(--s-color)">You (Arjun)</span><div class="lb-pts">315 pts</div></div>
        <div class="lb-row"><div class="lb-rank">#5</div><span style="flex:1;font-size:13px">Aditya Nair</span><div class="lb-pts">290 pts</div></div>
        <p style="font-size:11px;color:var(--muted);margin-top:12px">Live updates via Azure SignalR · Resets every Monday</p>
      </div>
    </div>
    <div class="card" id="doubt-panel" style="display:none;margin-bottom:18px">
      <div class="card-hd">
        <span class="card-title">💬 AI Doubt Buddy</span>
        <div style="display:flex;gap:8px;align-items:center">
          <select class="lang-sel" id="doubt-lang"><option value="en">🇬🇧 English</option><option value="hi">🇮🇳 Hindi</option><option value="kn">🏳️ Kannada</option><option value="ta">🏳️ Tamil</option><option value="te">🏳️ Telugu</option></select>
          <button class="btn btn-g" style="font-size:11px;padding:6px 12px" onclick="closeDoubt()">✕ Close</button>
        </div>
      </div>
      <div class="pomo-sub-tabs" style="justify-content:flex-start;margin-bottom:12px">
        <button class="pomo-tab" onclick="selectSubDoubt(this)">📐 Maths</button>
        <button class="pomo-tab" onclick="selectSubDoubt(this)">⚛ Physics</button>
        <button class="pomo-tab active" onclick="selectSubDoubt(this)">🧪 Chemistry</button>
        <button class="pomo-tab" onclick="selectSubDoubt(this)">🌿 Biology</button>
      </div>
      <div class="chat-area" id="chat-area">
        <div class="chat-msg ai"><div class="bot-av">🤖</div><div class="bubble">Hi Arjun! Chemistry is your weak spot. What's your doubt? I'll explain simply — or switch language above 🌐</div></div>
        <div class="chat-msg user"><div class="bubble">What is covalent bonding?</div></div>
        <div class="chat-msg ai"><div class="bot-av">🤖</div><div class="bubble">🧪 <strong>Covalent bonding</strong> = two atoms <em>share</em> electrons.<br><br>Example: H₂O — Oxygen shares one electron each with two Hydrogen atoms. Like two friends sharing a pizza! 🍕</div></div>
      </div>
      <div class="chat-row">
        <input class="chat-inp" id="chat-inp" placeholder="Type your doubt here..." onkeydown="if(event.key==='Enter')sendChat()">
        <button class="btn btn-s" onclick="sendChat()">Send ↗</button>
      </div>
      <p style="font-size:11px;color:var(--muted);margin-top:10px">Azure Translator converts replies to your selected language</p>
    </div>
    <div class="card">
      <div class="card-hd"><span class="card-title">📊 Subject Progress — This Month</span><span class="badge bs">March 2026</span></div>
      <div style="padding-top:4px">
        <div class="rep-row"><div class="rep-name">Maths</div><div class="pbar" style="flex:1"><div class="pfill" style="width:85%;background:var(--success)"></div></div><div class="rep-pct" style="color:var(--success)">85%</div></div>
        <div class="rep-row"><div class="rep-name">Physics</div><div class="pbar" style="flex:1"><div class="pfill" style="width:72%;background:var(--s-color)"></div></div><div class="rep-pct" style="color:var(--s-color)">72%</div></div>
        <div class="rep-row"><div class="rep-name">Chemistry</div><div class="pbar" style="flex:1"><div class="pfill" style="width:48%;background:var(--danger)"></div></div><div class="rep-pct" style="color:var(--danger)">48%</div></div>
        <div class="rep-row"><div class="rep-name">Biology</div><div class="pbar" style="flex:1"><div class="pfill" style="width:79%;background:var(--warn)"></div></div><div class="rep-pct" style="color:var(--warn)">79%</div></div>
        <div class="rep-row"><div class="rep-name">History</div><div class="pbar" style="flex:1"><div class="pfill" style="width:91%;background:var(--success)"></div></div><div class="rep-pct" style="color:var(--success)">91%</div></div>
      </div>
    </div>
  </div>
</div>
<div class="screen" id="screen-teacher-dash">
  <nav class="topbar">
    <div class="topbar-logo t">GURUKULAi</div>
    <div class="topbar-center">👩‍🏫 Teacher Dashboard — Class X-A</div>
    <div class="topbar-right">
      <div class="avatar av-t">MS</div>
      <span style="font-size:13px;font-weight:600">Mrs. Sunitha</span>
      <button class="logout-btn" onclick="goScreen('screen-landing')">Logout</button>
    </div>
  </nav>
  <div class="dash-body">
    <div class="page-hd">
      <div><h1>Welcome back, <span style="color:var(--t-color)">Mrs. Sunitha 👩‍🏫</span></h1><p>Class X-A · 32 Students · Maths &amp; Physics · Unit Test 3 results pending</p></div>
      <button class="btn btn-t" onclick="runAnalysis()">🤖 Run AI Analysis</button>
    </div>
    <div class="qs-row">
      <div class="qs"><div class="qs-lbl">Class Average</div><div class="qs-val" style="color:var(--t-color)">68%</div></div>
      <div class="qs"><div class="qs-lbl">Strong</div><div class="qs-val" style="color:var(--success)">9</div><div class="qs-sub">≥ 75%</div></div>
      <div class="qs"><div class="qs-lbl">Average</div><div class="qs-val" style="color:var(--warn)">16</div><div class="qs-sub">50–74%</div></div>
      <div class="qs"><div class="qs-lbl">Need Support</div><div class="qs-val" style="color:var(--danger)">7</div><div class="qs-sub">&lt; 50%</div></div>
    </div>
    <div class="g2">
      <div class="card">
        <div class="card-hd"><span class="card-title">📝 Enter Marks</span><select class="lang-sel"><option>Maths — Unit Test 3</option><option>Physics — Unit Test 3</option><option>Chemistry — Unit Test 3</option></select></div>
        <table>
          <thead><tr><th>Student</th><th>Marks /100</th><th>Status</th></tr></thead>
          <tbody id="marks-tb">
            <tr><td>Arjun Rao</td><td><input type="number" value="78" min="0" max="100" onchange="updStatus(this)"></td><td><span class="badge bk">Average</span></td></tr>
            <tr><td>Sneha Reddy</td><td><input type="number" value="92" min="0" max="100" onchange="updStatus(this)"></td><td><span class="badge bk">Strong</span></td></tr>
            <tr><td>Rahul Kumar</td><td><input type="number" value="45" min="0" max="100" onchange="updStatus(this)"></td><td><span class="badge bd">Weak</span></td></tr>
            <tr><td>Priya Sharma</td><td><input type="number" value="88" min="0" max="100" onchange="updStatus(this)"></td><td><span class="badge bk">Strong</span></td></tr>
            <tr><td>Aditya Nair</td><td><input type="number" value="61" min="0" max="100" onchange="updStatus(this)"></td><td><span class="badge bw">Average</span></td></tr>
            <tr><td>Meera Iyer</td><td><input type="number" value="38" min="0" max="100" onchange="updStatus(this)"></td><td><span class="badge bd">Weak</span></td></tr>
          </tbody>
        </table>
        <div style="display:flex;gap:8px;margin-top:14px">
          <button class="btn btn-t" style="flex:1" onclick="saveMarks()">💾 Save to Azure SQL</button>
          <button class="btn btn-g" style="flex:1">📤 Import CSV</button>
        </div>
      </div>
      <div class="card">
        <div class="card-hd"><span class="card-title">🔥 Class Performance Heatmap</span><span class="badge bt">All Subjects</span></div>
        <p style="font-size:12px;color:var(--muted);margin-bottom:12px">Average score per subject across all students</p>
        <div class="heatmap">
          <div class="hmap hstr"><div class="hn">Maths</div><div class="hv">81</div></div>
          <div class="hmap havg"><div class="hn">Physics</div><div class="hv">69</div></div>
          <div class="hmap hwk"><div class="hn">Chemistry</div><div class="hv">52</div></div>
          <div class="hmap havg"><div class="hn">Biology</div><div class="hv">73</div></div>
          <div class="hmap hstr"><div class="hn">English</div><div class="hv">84</div></div>
          <div class="hmap hwk"><div class="hn">Hindi</div><div class="hv">55</div></div>
          <div class="hmap havg"><div class="hn">History</div><div class="hv">67</div></div>
          <div class="hmap hstr"><div class="hn">Geography</div><div class="hv">78</div></div>
          <div class="hmap hwk"><div class="hn">Economics</div><div class="hv">49</div></div>
          <div class="hmap havg"><div class="hn">Computer</div><div class="hv">72</div></div>
        </div>
        <div id="ai-rec" style="display:none;background:var(--t-dim);border:1px solid rgba(255,159,67,.2);border-radius:10px;padding:12px;margin-top:14px;font-size:12px;line-height:1.7">
          🤖 <strong>AI Recommendation:</strong> Chemistry (52%) and Economics (49%) are critical weak areas. 7 students score below 50%. Suggest: assign AI flashcards, schedule doubt sessions, and SMS parents of weak students immediately.
        </div>
      </div>
    </div>
    <div class="g2">
      <div class="card">
        <div class="card-hd"><span class="card-title">🤖 AI Student Classification</span><span class="badge bt">Auto-updated</span></div>
        <div>
          <div class="cl-row"><div class="cl-name">Sneha Reddy</div><div class="chip cstr">Strong</div><div class="cl-avg-val" style="margin-left:6px">Avg 91%</div></div>
          <div class="cl-row"><div class="cl-name">Priya Sharma</div><div class="chip cstr">Strong</div><div class="cl-avg-val" style="margin-left:6px">Avg 88%</div></div>
          <div class="cl-row"><div class="cl-name">Arjun Rao</div><div class="chip cavg">Average</div><div class="cl-avg-val" style="margin-left:6px">Avg 74%</div></div>
          <div class="cl-row"><div class="cl-name">Aditya Nair</div><div class="chip cavg">Average</div><div class="cl-avg-val" style="margin-left:6px">Avg 64%</div></div>
          <div class="cl-row"><div class="cl-name">Meera Iyer</div><div class="chip cwk">Weak</div><div class="cl-avg-val" style="margin-left:6px">Avg 41%</div></div>
          <div class="cl-row"><div class="cl-name">Rahul Kumar</div><div class="chip cwk">Weak</div><div class="cl-avg-val" style="margin-left:6px">Avg 38%</div></div>
        </div>
        <div style="margin-top:14px">
          <div class="bar-chart">
            <div class="bc"><div class="bv" style="color:var(--success)">Strong</div><div class="bar" style="height:56px;background:var(--success)"></div><div class="bl">9 stu</div></div>
            <div class="bc"><div class="bv" style="color:var(--warn)">Avg</div><div class="bar" style="height:100px;background:var(--warn)"></div><div class="bl">16 stu</div></div>
            <div class="bc"><div class="bv" style="color:var(--danger)">Weak</div><div class="bar" style="height:44px;background:var(--danger)"></div><div class="bl">7 stu</div></div>
          </div>
        </div>
      </div>
      <div class="card" style="border-color:rgba(255,159,67,.2)">
        <div class="card-hd"><span class="card-title">📱 Send SMS to Parents</span><span class="badge bt">Azure Communication Services</span></div>
        <div class="section-lbl">Target Group</div>
        <div class="sms-target">
          <button class="stag on" onclick="this.classList.toggle('on')">All Parents (32)</button>
          <button class="stag" onclick="this.classList.toggle('on')">Weak Only (7)</button>
          <button class="stag" onclick="this.classList.toggle('on')">Below 60% (13)</button>
          <button class="stag" onclick="this.classList.toggle('on')">Strong (9)</button>
        </div>
        <div class="section-lbl" style="margin-top:10px">Language</div>
        <div style="display:flex;gap:8px;margin-bottom:12px;flex-wrap:wrap">
          <select class="lang-sel" id="sms-lang" onchange="updateSMSPreview()"><option value="en">🇬🇧 English</option><option value="hi">🇮🇳 Hindi</option><option value="kn">🏳️ Kannada</option><option value="ta">🏳️ Tamil</option><option value="te">🏳️ Telugu</option></select>
          <span style="font-size:12px;color:var(--muted);align-self:center">Auto-translated via Azure Translator</span>
        </div>
        <div class="section-lbl">Message</div>
        <textarea class="sms-box" id="sms-msg" oninput="updateSMSPreview()">📊 Unit Test 3 results are out! Your ward scored 78/100 in Maths. Chemistry needs attention — AI study plan is active. — Mrs. Sunitha, GURUKULAi</textarea>
        <div style="display:flex;gap:8px;margin-top:10px">
          <button class="btn btn-t" style="flex:1" onclick="sendSMS()">📤 Send SMS via Azure</button>
          <button class="btn btn-g" onclick="aiDraftSMS()">🤖 AI Draft</button>
          <button class="btn btn-g" onclick="togglePreview()">👁 Preview</button>
        </div>
        <div class="sms-preview" id="sms-preview"><strong>📱 SMS Preview (Translated):</strong><br><span id="sms-preview-text"></span></div>
        <div id="sms-sent" style="display:none;font-size:12px;color:var(--success);font-weight:600;margin-top:10px">✅ SMS sent to 32 parents via Azure Communication Services!</div>
      </div>
    </div>
    <div class="card">
      <div class="card-hd"><span class="card-title">📅 Attendance — March 2026</span><span class="badge bt">Auto-alert if &lt;75%</span></div>
      <div class="bar-chart" style="height:110px;margin-top:8px">
        <div class="bc"><div class="bv" style="color:var(--success)">96%</div><div class="bar" style="height:96%;background:var(--success)"></div><div class="bl">Week 1</div></div>
        <div class="bc"><div class="bv" style="color:var(--success)">91%</div><div class="bar" style="height:91%;background:var(--success)"></div><div class="bl">Week 2</div></div>
        <div class="bc"><div class="bv" style="color:var(--warn)">78%</div><div class="bar" style="height:78%;background:var(--warn)"></div><div class="bl">Week 3</div></div>
        <div class="bc"><div class="bv" style="color:var(--t-color)">84%</div><div class="bar" style="height:84%;background:var(--t-color)"></div><div class="bl">Week 4</div></div>
      </div>
      <p style="font-size:11px;color:var(--muted);margin-top:10px">Azure Logic Apps auto-triggers SMS to parent when attendance drops below 75%</p>
    </div>
  </div>
</div>
<div class="modal-overlay" id="moti-modal">
  <div class="modal-box">
    <div class="modal-emoji" id="moti-emoji">🎉</div>
    <div class="modal-title">Session Complete!</div>
    <div class="modal-msg" id="moti-msg">You just finished a full 25-minute focused session!</div>
    <div class="modal-sub" id="moti-sub">Take a 5-minute break, then come back stronger 💪</div>
    <button class="btn btn-s" style="width:100%;justify-content:center" onclick="closeMoti()">🍅 Start Break Timer</button>
  </div>
</div>
<script>
const STUDY_DB = {
  Maths: {
    topics: [
      {icon:'📐',title:'Quadratic Equations',desc:'Roots, discriminant & formula',key:'quad'},
      {icon:'📊',title:'Statistics',desc:'Mean, median, mode & variance',key:'stats'},
      {icon:'🔺',title:'Trigonometry',desc:'Ratios, identities & applications',key:'trig'},
      {icon:'⭕',title:'Circles',desc:'Theorems, tangents & chords',key:'circles'},
    ],
    content: {
      quad:{title:'📐 Quadratic Equations',concepts:['A quadratic equation has the form ax² + bx + c = 0 where a ≠ 0','The highest power of the variable is 2','Every quadratic has exactly 2 roots','The discriminant D = b² - 4ac tells us the nature of roots'],formulas:['x = (−b ± √(b²−4ac)) / 2a','Sum of roots = −b/a','Product of roots = c/a','D > 0 → 2 real distinct roots · D = 0 → 2 equal roots · D < 0 → no real roots'],tip:'🧠 Trick: Always check if the equation can be factored first — it\'s faster!',quiz:[{q:'For x² - 5x + 6 = 0, what are the roots?',opts:['A) 2 and 3','B) 1 and 6','C) -2 and -3','D) 2 and -3'],ans:0},{q:'Discriminant of x² + 4x + 4 = 0?',opts:['A) 16','B) 8','C) 0','D) -16'],ans:2},{q:'If D < 0, the roots are:',opts:['A) Real & equal','B) Real & distinct','C) No real roots','D) Irrational'],ans:2}]},
      stats:{title:'📊 Statistics',concepts:['Mean = sum of all values ÷ total number of values','Median = middle value when data is arranged in order','Mode = value that appears most frequently in the data','Range = Maximum value − Minimum value'],formulas:['Mean (x̄) = Σx / n','Median = ((n/2)th + (n/2+1)th) / 2','Variance (σ²) = Σ(x−x̄)² / n','Standard Deviation (σ) = √Variance'],tip:'🧠 Mean is affected by outliers, but Median is NOT.',quiz:[{q:'Find mean of: 4, 7, 8, 9, 12',opts:['A) 7','B) 8','C) 8.5','D) 9'],ans:1},{q:'Which is not affected by extreme values?',opts:['A) Mean','B) Median','C) Range','D) Variance'],ans:1},{q:'Mode of: 2,3,3,4,5,5,5,6 is:',opts:['A) 3','B) 4','C) 5','D) 6'],ans:2}]},
      trig:{title:'🔺 Trigonometry',concepts:['Sin θ = Opposite / Hypotenuse (SOH)','Cos θ = Adjacent / Hypotenuse (CAH)','Tan θ = Opposite / Adjacent (TOA)','Memorise: SOH-CAH-TOA!'],formulas:['sin²θ + cos²θ = 1','1 + tan²θ = sec²θ','1 + cot²θ = cosec²θ','sin(A+B) = sinA·cosB + cosA·sinB'],tip:'🧠 For sin: 0°,30°,45°,60°,90° → 0, ½, 1/√2, √3/2, 1. Cos is the reverse!',quiz:[{q:'Value of sin 30°?',opts:['A) 1','B) 1/2','C) √3/2','D) 1/√2'],ans:1},{q:'sin²θ + cos²θ = ?',opts:['A) 0','B) 2','C) 1','D) sin2θ'],ans:2},{q:'tan 45° = ?',opts:['A) 0','B) 1/√2','C) √3','D) 1'],ans:3}]},
      circles:{title:'⭕ Circles',concepts:['Tangent to a circle is perpendicular to the radius at point of contact','Two tangents from an external point are always equal in length','Angle in a semicircle is always 90°','Equal chords are equidistant from the centre'],formulas:['Tangent length = √(d² - r²)','Area = πr²','Circumference = 2πr','Arc length = (θ/360) × 2πr'],tip:'🧠 Angle at centre = twice the angle at any other point on the circle.',quiz:[{q:'Tangent is perpendicular to:',opts:['A) Chord','B) Radius at contact point','C) Diameter','D) Another tangent'],ans:1},{q:'Two tangents from external point are:',opts:['A) Perpendicular','B) Parallel','C) Equal in length','D) Unequal'],ans:2},{q:'Angle in a semicircle is:',opts:['A) 45°','B) 60°','C) 90°','D) 180°'],ans:2}]}
    }
  },
  Physics: {
    topics: [
      {icon:'⚡',title:'Electricity',desc:'Ohm\'s law, circuits & resistance',key:'elec'},
      {icon:'💡',title:'Light',desc:'Reflection, refraction & lenses',key:'light'},
      {icon:'🚀',title:'Motion',desc:'Speed, velocity & Newton\'s laws',key:'motion'},
      {icon:'🔋',title:'Magnetic Effects',desc:'Magnetic field & induction',key:'magnet'},
    ],
    content: {
      elec:{title:'⚡ Electricity',concepts:['Electric current is the flow of electrons through a conductor','Ohm\'s Law: Voltage (V) = Current (I) × Resistance (R)','Series circuit: total resistance = R1 + R2 + R3','Parallel circuit: 1/R = 1/R1 + 1/R2 + 1/R3'],formulas:['V = IR (Ohm\'s Law)','Power P = VI = I²R = V²/R','Energy = Power × Time = VIt','Series: R_total = R1+R2 | Parallel: 1/R=1/R1+1/R2'],tip:'🧠 Series: current is SAME everywhere. Parallel: voltage is SAME across each branch.',quiz:[{q:'If V=12V and R=4Ω, current is?',opts:['A) 48A','B) 3A','C) 8A','D) 0.33A'],ans:1},{q:'In series circuit, what is constant?',opts:['A) Voltage','B) Resistance','C) Current','D) Power'],ans:2},{q:'Unit of resistance is:',opts:['A) Volt','B) Ampere','C) Watt','D) Ohm'],ans:3}]},
      light:{title:'💡 Light',concepts:['Angle of incidence = Angle of reflection','Light bends when passing from one medium to another — refraction','Convex lens converges light rays','Concave lens diverges light rays'],formulas:['Mirror: 1/v + 1/u = 1/f','Magnification m = -v/u','Snell\'s Law: n1·sin i = n2·sin r','Lens: 1/v - 1/u = 1/f'],tip:'🧠 Distances in direction of incident light = positive. Opposite = negative.',quiz:[{q:'Convex mirror always forms:',opts:['A) Real, inverted','B) Virtual, erect','C) Real, erect','D) Virtual, inverted'],ans:1},{q:'Law of reflection states:',opts:['A) Snell\'s law','B) Refraction','C) i = r','D) Lens formula'],ans:2},{q:'Focal length of concave mirror is:',opts:['A) Positive','B) Negative','C) Zero','D) Infinity'],ans:1}]},
      motion:{title:'🚀 Motion & Newton\'s Laws',concepts:['Speed = Distance / Time (scalar)','Velocity = Displacement / Time (vector)','Newton\'s 1st: Object at rest stays at rest unless force acts','Newton\'s 2nd: Force = mass × acceleration (F = ma)','Newton\'s 3rd: Every action has equal & opposite reaction'],formulas:['v = u + at','s = ut + ½at²','v² = u² + 2as','F = ma','Momentum p = mv'],tip:'🧠 These 3 equations work only when acceleration is CONSTANT!',quiz:[{q:'Car from rest reaches 20m/s in 4s. Acceleration?',opts:['A) 80m/s²','B) 5m/s²','C) 0.2m/s²','D) 4m/s²'],ans:1},{q:'Newton\'s 2nd law gives:',opts:['A) Law of inertia','B) F = ma','C) Action-reaction','D) Gravitation'],ans:1},{q:'Unit of momentum:',opts:['A) N·m','B) kg·m/s','C) kg/m·s','D) m/s²'],ans:1}]},
      magnet:{title:'🔋 Magnetic Effects',concepts:['Current-carrying conductor produces a magnetic field','Fleming\'s Left Hand Rule: force on conductor in magnetic field','Electromagnetic induction: moving magnet near coil produces current','Transformers work on electromagnetic induction'],formulas:['Force F = BIL sinθ','Solenoid: B = μ₀nI','Transformer: Vs/Vp = Ns/Np','Ideal: VpIp = VsIs'],tip:'🧠 Left Hand = Motor effect. Right Hand = Generator effect. L for Motor!',quiz:[{q:'Electromagnetic induction discovered by:',opts:['A) Newton','B) Faraday','C) Ohm','D) Fleming'],ans:1},{q:'Step-up transformer:',opts:['A) Increases current','B) Increases voltage','C) Decreases voltage','D) Less secondary turns'],ans:1},{q:'Fleming\'s Left Hand Rule is for:',opts:['A) Generators','B) Transformers','C) Motors','D) Capacitors'],ans:2}]}
    }
  },
  Chemistry: {
    topics: [
      {icon:'⚗️',title:'Chemical Reactions',desc:'Types, balancing & indicators',key:'rxn'},
      {icon:'🧪',title:'Acids & Bases',desc:'pH scale, neutralisation & salts',key:'acid'},
      {icon:'⚛️',title:'Periodic Table',desc:'Groups, periods & trends',key:'periodic'},
      {icon:'🔗',title:'Chemical Bonding',desc:'Ionic, covalent & metallic bonds',key:'bond'},
    ],
    content: {
      rxn:{title:'⚗️ Chemical Reactions',concepts:['A chemical reaction involves breaking old bonds and forming new ones','Law of Conservation of Mass: mass is neither created nor destroyed','Combination: A + B → AB','Decomposition: AB → A + B','Displacement: A + BC → AC + B'],formulas:['Combination: Fe + S → FeS','Decomposition: 2H₂O → 2H₂ + O₂','Displacement: Zn + CuSO₄ → ZnSO₄ + Cu','Double Displacement: NaCl + AgNO₃ → NaNO₃ + AgCl↓'],tip:'🧠 To balance: count atoms on both sides. Never change a formula — only add coefficients!',quiz:[{q:'2Mg + O₂ → 2MgO is:',opts:['A) Decomposition','B) Displacement','C) Combination','D) Double displacement'],ans:2},{q:'Displacement reaction means:',opts:['A) Compounds exchange ions','B) Element replaces another in compound','C) Compound breaks down','D) Two substances combine'],ans:1},{q:'Rusting of iron is:',opts:['A) Physical change','B) Decomposition','C) Oxidation reaction','D) Combination only'],ans:2}]},
      acid:{title:'🧪 Acids, Bases & Salts',concepts:['Acids taste sour, turn blue litmus red. pH < 7','Bases taste bitter, feel soapy, turn red litmus blue. pH > 7','Neutral solutions have pH = 7 (pure water)','Neutralisation: Acid + Base → Salt + Water'],formulas:['HCl → H⁺ + Cl⁻  (Strong acid)','NaOH → Na⁺ + OH⁻  (Strong base)','HCl + NaOH → NaCl + H₂O','pH: 0 (most acidic) → 7 (neutral) → 14 (most basic)'],tip:'🧠 pH = -log[H⁺]. Every 1 unit decrease in pH = 10 times more acidic!',quiz:[{q:'pH of lemon juice is:',opts:['A) 2','B) 7','C) 10','D) 14'],ans:0},{q:'Acid + Base → ?',opts:['A) Only salt','B) Only water','C) Salt + Water','D) Gas + Salt'],ans:2},{q:'Which turns red litmus blue?',opts:['A) HCl','B) H₂SO₄','C) NaOH','D) Vinegar'],ans:2}]},
      periodic:{title:'⚛️ Periodic Table',concepts:['Elements arranged in increasing order of atomic number','Periods (rows): same period = same number of electron shells','Groups (columns): same group = same number of valence electrons','Atomic radius decreases across a period (left to right)','Atomic radius increases down a group'],formulas:['Valence electrons = Group number','Max electrons in shell n = 2n²','First shell: 2, Second: 8, Third: 18','Noble gases (Group 18) = full outermost shells'],tip:'🧠 Metals on left, Non-metals on right, Metalloids in between.',quiz:[{q:'Atomic number 6 is:',opts:['A) Nitrogen','B) Carbon','C) Oxygen','D) Boron'],ans:1},{q:'Same group = same number of:',opts:['A) Protons','B) Neutrons','C) Valence electrons','D) Shells'],ans:2},{q:'Noble gases have valency of:',opts:['A) 1','B) 2','C) 0','D) 8'],ans:2}]},
      bond:{title:'🔗 Chemical Bonding',concepts:['Ionic bond: transfer of electrons between metal and non-metal','Covalent bond: sharing of electrons between two non-metals','Ionic compounds have high melting points and conduct electricity when dissolved','Covalent compounds are generally poor conductors'],formulas:['NaCl: Na⁺ + Cl⁻ → ionic bond','H₂O: H-O-H → covalent bond','CO₂: O=C=O → double covalent','N₂: N≡N → triple covalent'],tip:'🧠 Metal + Non-metal = Ionic. Non-metal + Non-metal = Covalent.',quiz:[{q:'NaCl is an example of:',opts:['A) Covalent','B) Metallic','C) Ionic','D) Hydrogen bond'],ans:2},{q:'Covalent bonds formed by:',opts:['A) Transfer of electrons','B) Sharing of electrons','C) Attraction of ions','D) Loss of protons'],ans:1},{q:'H₂O has how many covalent bonds?',opts:['A) 1','B) 2','C) 3','D) 4'],ans:1}]}
    }
  },
  Biology: {
    topics: [
      {icon:'🌱',title:'Life Processes',desc:'Nutrition, respiration & excretion',key:'life'},
      {icon:'🧬',title:'Heredity & Evolution',desc:'Genetics, DNA & natural selection',key:'heredity'},
      {icon:'🦠',title:'Control & Coordination',desc:'Nervous system & hormones',key:'control'},
      {icon:'🌿',title:'How Plants Reproduce',desc:'Sexual & asexual reproduction',key:'plants'},
    ],
    content: {
      life:{title:'🌱 Life Processes',concepts:['Nutrition: taking in food and using it for energy and growth','Respiration: breaking down glucose to release energy','Transportation: moving substances around the body','Excretion: removing waste products from the body'],formulas:['Photosynthesis: 6CO₂ + 6H₂O + Light → C₆H₁₂O₆ + 6O₂','Aerobic Respiration: C₆H₁₂O₆ + 6O₂ → 6CO₂ + 6H₂O + Energy','Anaerobic: Glucose → Lactic acid + Energy','Yeast: Glucose → Alcohol + CO₂ + Energy'],tip:'🧠 Photosynthesis and respiration are OPPOSITES!',quiz:[{q:'Photosynthesis occurs in:',opts:['A) Mitochondria','B) Ribosome','C) Chloroplast','D) Nucleus'],ans:2},{q:'Phloem transports:',opts:['A) Water','B) Minerals','C) Food (sugars)','D) Oxygen'],ans:2},{q:'Kidneys are organs of:',opts:['A) Nutrition','B) Respiration','C) Excretion','D) Reproduction'],ans:2}]},
      heredity:{title:'🧬 Heredity & Evolution',concepts:['Heredity: passing of traits from parents to offspring through genes','DNA carries the genetic information','Chromosomes are thread-like structures that carry genes','Humans have 46 chromosomes (23 pairs)','Natural selection: organisms with favourable traits survive more'],formulas:['Humans: 46 chromosomes (23 pairs)','XX = Female, XY = Male','Mendel: Dominant masks recessive in F1','Genotype = genetic makeup | Phenotype = physical appearance'],tip:'🧠 Tt × Tt cross gives 3 Tall : 1 Short in F2 generation.',quiz:[{q:'DNA stands for:',opts:['A) Deoxyribonucleic Acid','B) Diribonucleic Acid','C) Deoxyribose Amino Acid','D) Dinitrogenous Acid'],ans:0},{q:'Chromosomes in human body cell?',opts:['A) 23','B) 44','C) 46','D) 48'],ans:2},{q:'Theory of natural selection:',opts:['A) Mendel','B) Darwin','C) Lamarck','D) Watson'],ans:1}]},
      control:{title:'🦠 Control & Coordination',concepts:['Nervous system: brain, spinal cord and nerves control body quickly','Neuron (nerve cell): basic unit of nervous system','Reflex action: automatic response without conscious thought','Endocrine system: glands release hormones for slower control'],formulas:['Reflex arc: Stimulus→Receptor→Sensory nerve→Spinal cord→Motor nerve→Effector','Adrenaline: fight or flight hormone','Insulin: released by pancreas to lower blood sugar','Thyroxine: controls metabolic rate'],tip:'🧠 Nervous system = fast (milliseconds). Endocrine = slow (minutes to hours).',quiz:[{q:'Basic unit of nervous system:',opts:['A) Brain','B) Neuron','C) Nerve','D) Synapse'],ans:1},{q:'Insulin produced by:',opts:['A) Liver','B) Kidney','C) Pancreas','D) Thyroid'],ans:2},{q:'Reflex actions controlled by:',opts:['A) Brain','B) Cerebellum','C) Spinal cord','D) Hypothalamus'],ans:2}]},
      plants:{title:'🌿 Reproduction in Plants',concepts:['Asexual: one parent needed (vegetative propagation, budding, spores)','Sexual: fusion of male and female gametes','Pollination: transfer of pollen from anther to stigma','Fertilisation: fusion of pollen nucleus with egg cell in ovule'],formulas:['Self-pollination: pollen to SAME flower\'s stigma','Cross-pollination: pollen to DIFFERENT flower','Agents: wind, water, insects, birds','Seed = Fertilised ovule | Fruit = Ripened ovary'],tip:'🧠 After fertilisation: Ovule→Seed, Ovary→Fruit. This sequence is important!',quiz:[{q:'Transfer of pollen to stigma is:',opts:['A) Fertilisation','B) Pollination','C) Germination','D) Reproduction'],ans:1},{q:'Example of asexual reproduction:',opts:['A) Seed formation','B) Budding in yeast','C) Vegetative propagation','D) Pollination'],ans:2},{q:'After fertilisation, ovary becomes:',opts:['A) Seed','B) Fruit','C) Flower','D) Pollen'],ans:1}]}
    }
  },
  History: {
    topics: [
      {icon:'🏭',title:'Industrial Revolution',desc:'Rise of industries & social impact',key:'indust'},
      {icon:'🌍',title:'Nationalism in Europe',desc:'Rise of nation-states & movements',key:'nation'},
      {icon:'🇮🇳',title:'Indian Independence',desc:'Freedom struggle & key leaders',key:'india'},
      {icon:'🌐',title:'Globalisation',desc:'Trade, economy & world connections',key:'global'},
    ],
    content: {
      indust:{title:'🏭 Industrial Revolution',concepts:['Industrial Revolution began in Britain around 1760s-1840s','Shift from hand tools to large-scale factory production','Steam engine (James Watt, 1769) was the most important invention','Child labour was widespread in factories and mines','Led to growth of cities (urbanisation) and new social classes'],formulas:['Key inventions: Steam engine (Watt), Spinning jenny (Hargreaves), Power loom (Cartwright)','Enclosure movement → peasants lost land → moved to cities','Factory system → capitalism → new working class','Britain called "Workshop of the World"'],tip:'🧠 Why Britain first? — Coal & iron, overseas trade, political stability, entrepreneurial spirit.',quiz:[{q:'Industrial Revolution began in:',opts:['A) France','B) Germany','C) Britain','D) USA'],ans:2},{q:'Steam engine invented by:',opts:['A) Newton','B) James Watt','C) Edison','D) Faraday'],ans:1},{q:'Industrial Revolution led to growth of:',opts:['A) Agriculture','B) Villages','C) Cities','D) Feudalism'],ans:2}]},
      nation:{title:'🌍 Rise of Nationalism in Europe',concepts:['Nationalism: belief that people of common identity should form their own nation','French Revolution (1789) spread liberty, equality and nationalism','Napoleon Bonaparte spread revolutionary ideas across Europe','Germany unified in 1871 under Bismarck','Italy unified in 1861 under Garibaldi and Cavour'],formulas:['1789: French Revolution','1848: Year of Revolutions','1861: Italian Unification (Risorgimento)','1871: German Unification under Kaiser Wilhelm I'],tip:'🧠 Bismarck (Germany) used war & politics. Garibaldi (Italy) used popular military force.',quiz:[{q:'French Revolution occurred in:',opts:['A) 1776','B) 1789','C) 1848','D) 1871'],ans:1},{q:'Germany unified under:',opts:['A) Napoleon','B) Garibaldi','C) Bismarck','D) Mazzini'],ans:2},{q:'Risorgimento refers to unification of:',opts:['A) Germany','B) France','C) Italy','D) Austria'],ans:2}]},
      india:{title:'🇮🇳 Indian Independence Movement',concepts:['British East India Company came in 1600, Raj after 1857 revolt','Indian National Congress founded in 1885','Gandhi\'s key movements: Non-Cooperation (1920), Civil Disobedience (1930), Quit India (1942)','Salt March (Dandi March) 1930 — walked 241 miles to make salt','India gained independence on 15 August 1947'],formulas:['1885: INC founded by A.O. Hume','1919: Jallianwala Bagh massacre','1930: Dandi March','1942: Quit India Movement ("Do or Die")','1947: Independence — Partition into India and Pakistan'],tip:'🧠 Gandhi: Ahimsa + Satyagraha. Movements in order: Non-Cooperation → Civil Disobedience → Quit India.',quiz:[{q:'INC was founded in:',opts:['A) 1857','B) 1885','C) 1905','D) 1920'],ans:1},{q:'Dandi March was against:',opts:['A) Tax on cloth','B) Tax on salt','C) Partition of Bengal','D) Rowlatt Act'],ans:1},{q:'India gained independence on:',opts:['A) 26 Jan 1947','B) 15 Aug 1947','C) 15 Aug 1950','D) 26 Jan 1950'],ans:1}]},
      global:{title:'🌐 Globalisation',concepts:['Globalisation: integration of economies, cultures and societies worldwide','MNCs (Multinational Corporations) operate across many countries','WTO (World Trade Organisation) promotes free trade','Benefits: more choice, lower prices, economic growth','Concerns: loss of local industries, inequality'],formulas:['WTO: World Trade Organisation (est. 1995)','IMF: International Monetary Fund','FDI: Foreign Direct Investment','GDP: Gross Domestic Product'],tip:'🧠 Globalisation helped India\'s IT sector but hurt small local manufacturers.',quiz:[{q:'WTO stands for:',opts:['A) World Trade Organisation','B) World Tourism Organisation','C) World Technology Organisation','D) World Treaty Organisation'],ans:0},{q:'MNC means:',opts:['A) Modern National Company','B) Multinational Corporation','C) Manufacturing Net Company','D) Market National Corporation'],ans:1},{q:'Globalisation mainly benefits which Indian sector?',opts:['A) Agriculture','B) Handicrafts','C) IT & Services','D) Small industries'],ans:2}]}
    }
  }
};

let currentStudySub='Maths';let quizAnswered={};
function loadStudyMaterial(btn,subject){
  document.querySelectorAll('#study-tabs .pomo-tab').forEach(t=>t.classList.remove('active'));
  if(btn)btn.classList.add('active');
  currentStudySub=subject;
  document.getElementById('study-sync-label').textContent=subject;
  document.getElementById('study-content-box').classList.remove('show');
  quizAnswered={};
  const loading=document.getElementById('study-loading');
  const grid=document.getElementById('study-topic-grid');
  loading.style.display='block';grid.style.display='none';
  setTimeout(()=>{loading.style.display='none';grid.style.display='grid';renderTopics(subject);},600);
}
function renderTopics(subject){
  const data=STUDY_DB[subject];if(!data)return;
  const grid=document.getElementById('study-topic-grid');
  grid.innerHTML=data.topics.map(t=>`<div class="study-topic-card" onclick="openTopic('${subject}','${t.key}',this)"><div class="stc-icon">${t.icon}</div><div class="stc-title">${t.title}</div><div class="stc-desc">${t.desc}</div></div>`).join('');
}
function openTopic(subject,key,card){
  document.querySelectorAll('.study-topic-card').forEach(c=>c.classList.remove('active'));
  if(card)card.classList.add('active');
  const content=STUDY_DB[subject]?.content?.[key];if(!content)return;
  document.getElementById('study-content-title').textContent=content.title;
  document.getElementById('study-content-box').classList.add('show');
  quizAnswered={};
  const body=document.getElementById('study-content-body');
  body.innerHTML=`
    <div class="study-section"><div class="study-section-label">📖 Key Concepts</div>${content.concepts.map(c=>`<div class="study-point"><div class="study-point-dot"></div><div>${c}</div></div>`).join('')}</div>
    <div class="study-section"><div class="study-section-label">🧮 Formulas & Rules</div>${content.formulas.map(f=>`<div class="formula-box">${f}</div>`).join('')}</div>
    <div class="study-section"><div class="study-section-label">💡 AI Study Tip</div><div class="tip-box">${content.tip}</div></div>
    <div class="study-section"><div class="study-section-label">🎯 Practice Questions</div>${content.quiz.map((q,qi)=>`<div class="quiz-q" id="quiz-q-${qi}"><div class="quiz-q-text">${qi+1}. ${q.q}</div><div class="quiz-opts">${q.opts.map((o,oi)=>`<button class="quiz-opt" onclick="ansQuiz(${qi},${oi},${q.ans})" id="qopt-${qi}-${oi}">${o}</button>`).join('')}</div></div>`).join('')}</div>`;
  body.scrollIntoView({behavior:'smooth',block:'nearest'});
}
function ansQuiz(qi,chosen,correct){
  if(quizAnswered[qi])return;quizAnswered[qi]=true;
  document.querySelectorAll(`#quiz-q-${qi} .quiz-opt`).forEach(b=>b.disabled=true);
  const cb=document.getElementById(`qopt-${qi}-${chosen}`);
  const rb=document.getElementById(`qopt-${qi}-${correct}`);
  if(chosen===correct){cb.classList.add('correct');cb.textContent='✅ '+cb.textContent;}
  else{cb.classList.add('wrong');cb.textContent='❌ '+cb.textContent;rb.classList.add('correct');rb.textContent='✅ '+rb.textContent;}
}
function closeStudyContent(){document.getElementById('study-content-box').classList.remove('show');document.querySelectorAll('.study-topic-card').forEach(c=>c.classList.remove('active'));quizAnswered={};}

function goScreen(id){document.querySelectorAll('.screen').forEach(s=>{s.classList.remove('show');s.style.display='none';});const s=document.getElementById(id);s.style.display='flex';s.classList.add('show');window.scrollTo(0,0);}
function goLogin(role){goScreen('screen-login-'+role);}
function loginStudent(){goScreen('screen-student-dash');}
function loginTeacher(){goScreen('screen-teacher-dash');}
function fillStudentDemo(){document.getElementById('s-id').value='STU2026042';document.getElementById('s-pw').value='arjun@123';}
function fillTeacherDemo(){document.getElementById('t-id').value='TCH20260014';document.getElementById('t-pw').value='sunitha@gk';}
goScreen('screen-landing');
function setMood(btn,msg){document.getElementById('mood-out').textContent=msg;}

let pomoState={running:false,paused:false,sec:25*60,totalSec:25*60,session:1,sub:'Maths',interval:null};
const circumference=364.4;
function updateRing(){document.getElementById('pomo-ring').style.strokeDashoffset=circumference*(1-pomoState.sec/pomoState.totalSec);}
function updateDisplay(){const m=String(Math.floor(pomoState.sec/60)).padStart(2,'0');const s=String(pomoState.sec%60).padStart(2,'0');document.getElementById('pomo-display').textContent=m+':'+s;updateRing();}
function togglePomo(){
  const btn=document.getElementById('pomo-start-btn');
  if(!pomoState.running){
    pomoState.running=true;pomoState.paused=false;btn.textContent='⏸ Pause';btn.className='btn btn-g';
    pomoState.interval=setInterval(()=>{
      pomoState.sec--;updateDisplay();
      if(pomoState.sec<=0){
        clearInterval(pomoState.interval);pomoState.running=false;pomoState.sec=pomoState.totalSec;updateDisplay();
        btn.textContent='▶ Start';btn.className='btn btn-s';
        showMoti(pomoState.sub,pomoState.session);pomoState.session++;
        document.getElementById('pomo-session-badge').textContent='Session '+pomoState.session+' of 4';
      }
    },1000);
  }else{clearInterval(pomoState.interval);pomoState.running=false;pomoState.paused=true;btn.textContent='▶ Resume';btn.className='btn btn-s';}
}
function resetPomo(){clearInterval(pomoState.interval);pomoState.running=false;pomoState.paused=false;pomoState.sec=pomoState.totalSec;updateDisplay();const btn=document.getElementById('pomo-start-btn');btn.textContent='▶ Start';btn.className='btn btn-s';}
function switchPomoSub(btn,sub){
  if(pomoState.running){alert('⏸ Pause or reset the timer before switching subject.');return;}
  document.querySelectorAll('.pomo-tab').forEach(t=>t.classList.remove('active'));
  btn.classList.add('active');pomoState.sub=sub;document.getElementById('pomo-sub-label').textContent=sub;
  const studyTabs=document.querySelectorAll('#study-tabs .pomo-tab');
  const subNames=['Maths','Physics','Chemistry','Biology','History'];
  studyTabs.forEach((t,i)=>{t.classList.remove('active');if(subNames[i]===sub)t.classList.add('active');});
  loadStudyMaterial(null,sub);
}
const motiMessages=[
  {emoji:'🎯',msg:'25 minutes of deep focus done. That\'s how champions are built — one session at a time.',sub:'You\'re doing better than 80% of your classmates today.'},
  {emoji:'🔥',msg:'Two sessions done! Your brain is in peak learning mode right now.',sub:'Only 2 more sessions to a perfect study day!'},
  {emoji:'🚀',msg:'Three sessions! You\'re on fire. Most students give up at session one.',sub:'One more and you\'ve hit your daily goal. Let\'s go!'},
  {emoji:'🏆',msg:'FOUR sessions complete! You\'ve conquered the full Pomodoro cycle!',sub:'Today\'s hard work is tomorrow\'s good marks. Incredible!'},
];
function showMoti(sub,session){const m=motiMessages[Math.min(session-1,motiMessages.length-1)];document.getElementById('moti-emoji').textContent=m.emoji;document.getElementById('moti-msg').textContent=m.msg;document.getElementById('moti-sub').textContent='Subject: '+sub+' · '+m.sub;document.getElementById('moti-modal').classList.add('show');}
function closeMoti(){document.getElementById('moti-modal').classList.remove('show');}
function ansGK(btn,res){document.querySelectorAll('.gk-opt').forEach(b=>b.disabled=true);if(res==='correct'){btn.style.background='rgba(6,214,160,.2)';btn.style.borderColor='var(--success)';document.getElementById('gk-result').style.display='block';}else{btn.style.background='rgba(255,84,112,.15)';btn.style.borderColor='var(--danger)';}}
const fcData=[
  {q:'What is the atomic number of Carbon?',a:'6',hint:'Carbon has 6 protons in its nucleus'},
  {q:"What is Avogadro's number?",a:'6.022 × 10²³',hint:'Number of particles in one mole of substance'},
  {q:'Chemical formula for Sulphuric Acid?',a:'H₂SO₄',hint:'2 Hydrogen, 1 Sulphur, 4 Oxygen atoms'},
  {q:'What is the pH of pure water?',a:'7',hint:'Neutral — neither acidic nor basic'},
  {q:'What is the valency of Oxygen?',a:'2',hint:'Oxygen needs 2 more electrons to complete its shell'},
  {q:'Atomic number of Gold?',a:'79',hint:'Symbol Au from Latin "Aurum"'},
  {q:'Chemical name of baking soda?',a:'Sodium Bicarbonate (NaHCO₃)',hint:'Commonly used in cooking and antacids'},
  {q:'Gas produced: acid + metal?',a:'Hydrogen (H₂)',hint:'Burns with a "pop" sound'},
  {q:'Formula of common salt?',a:'NaCl',hint:'Sodium Chloride — Sodium + Chlorine'},
  {q:'Atomic number of Nitrogen?',a:'7',hint:'N is the 7th element'},
  {q:"Newton's First Law?",a:'Object stays at rest unless external force acts',hint:'Also called Law of Inertia'},
  {q:'SI unit of Force?',a:'Newton (N)',hint:'1 Newton = 1 kg·m/s²'},
  {q:'Formula for Kinetic Energy?',a:'KE = ½mv²',hint:'m = mass, v = velocity'},
  {q:'Speed of light in vacuum?',a:'3 × 10⁸ m/s',hint:'~300,000 km per second'},
  {q:'Unit of electric resistance?',a:'Ohm (Ω)',hint:'Named after Georg Simon Ohm'},
  {q:"Ohm's Law?",a:'V = IR',hint:'Voltage = Current × Resistance'},
  {q:'SI unit of Power?',a:'Watt (W)',hint:'1 Watt = 1 Joule per second'},
  {q:'Acceleration due to gravity on Earth?',a:'9.8 m/s²',hint:'Often approximated as 10 m/s²'},
  {q:'Value of π (2 decimal)?',a:'3.14',hint:'Ratio of circumference to diameter'},
  {q:'Area of circle (radius r)?',a:'πr²',hint:'π times radius squared'},
  {q:'Pythagoras Theorem?',a:'a² + b² = c²',hint:'c is the hypotenuse'},
  {q:'Sum of angles in triangle?',a:'180°',hint:'Always true on flat surface'},
  {q:'Simple Interest formula?',a:'SI = (P × R × T) / 100',hint:'Principal × Rate × Time ÷ 100'},
  {q:'Quadratic formula?',a:'x = (−b ± √(b²−4ac)) / 2a',hint:'Solves ax² + bx + c = 0'},
  {q:'Powerhouse of the cell?',a:'Mitochondria',hint:'Produces ATP energy'},
  {q:'Basic unit of life?',a:'Cell',hint:'All organisms made of cells'},
  {q:'Full form of DNA?',a:'Deoxyribonucleic Acid',hint:'Carries genetic information'},
  {q:'Photosynthesis occurs in?',a:'Chloroplast',hint:'Contains green chlorophyll'},
  {q:'Chromosomes in human cell?',a:'46 (23 pairs)',hint:'23 from father + 23 from mother'},
  {q:'Who wrote Indian National Anthem?',a:'Rabindranath Tagore',hint:'First Asian Nobel Prize winner'},
  {q:'India independence date?',a:'15 August 1947',hint:'After 200 years of British rule'},
  {q:'Father of Indian Constitution?',a:'Dr. B.R. Ambedkar',hint:'Chairman of Drafting Committee'},
  {q:'Largest planet in Solar System?',a:'Jupiter',hint:'1300 Earths can fit inside'},
  {q:'Capital of Australia?',a:'Canberra',hint:'Not Sydney — common mistake!'},
  {q:'Chemical symbol of Iron?',a:'Fe',hint:'From Latin word "Ferrum"'},
];
function shuffle(arr){return arr.map(v=>({v,s:Math.random()})).sort((a,b)=>a.s-b.s).map(x=>x.v);}
let fcDeck=shuffle([...fcData]);let fcIdx=0;
function updateFCBadge(){document.getElementById('fc-count').textContent=(fcDeck.length-fcIdx)+' left today';}
function flipFC(){document.getElementById('flashcard').classList.toggle('flipped');}
function nextFC(){document.getElementById('flashcard').classList.remove('flipped');fcIdx++;if(fcIdx>=fcDeck.length){fcDeck=shuffle([...fcData]);fcIdx=0;}updateFCBadge();setTimeout(()=>{document.getElementById('fc-q').textContent=fcDeck[fcIdx].q;document.getElementById('fc-a').textContent=fcDeck[fcIdx].a;document.getElementById('fc-hint').textContent=fcDeck[fcIdx].hint;},280);}
updateFCBadge();
function openDoubt(){document.getElementById('doubt-panel').style.display='block';document.getElementById('doubt-panel').scrollIntoView({behavior:'smooth',block:'nearest'});}
function closeDoubt(){document.getElementById('doubt-panel').style.display='none';}
function selectSubDoubt(btn){document.querySelectorAll('#doubt-panel .pomo-tab').forEach(t=>t.classList.remove('active'));btn.classList.add('active');}
function sendChat(){const inp=document.getElementById('chat-inp');const msg=inp.value.trim();if(!msg)return;const area=document.getElementById('chat-area');area.innerHTML+=`<div class="chat-msg user"><div class="bubble">${msg}</div></div>`;inp.value='';setTimeout(()=>{area.innerHTML+=`<div class="chat-msg ai"><div class="bot-av">🤖</div><div class="bubble">Great question! 🧠<br><br>This explanation is generated from your selected subject context. Azure Translator will convert this reply to your preferred language if switched above.</div></div>`;area.scrollTop=area.scrollHeight;},700);area.scrollTop=area.scrollHeight;}
function updStatus(inp){const v=parseInt(inp.value);const bd=inp.closest('tr').querySelector('.badge');if(v>=75){bd.className='badge bk';bd.textContent='Strong';}else if(v>=50){bd.className='badge bw';bd.textContent='Average';}else{bd.className='badge bd';bd.textContent='Weak';}}
function saveMarks(){alert('✅ Marks saved to Azure SQL!\n\nAzure Function triggered:\n→ Classification updated\n→ Weak student list refreshed\n→ Parent SMS queue ready');}
function runAnalysis(){document.getElementById('ai-rec').style.display='block';document.getElementById('ai-rec').scrollIntoView({behavior:'smooth',block:'nearest'});}
const smsT={en:'📊 Unit Test 3 results are out! Your ward scored 78/100 in Maths. Chemistry needs attention — AI study plan is active. — Mrs. Sunitha, GURUKULAi',hi:'📊 यूनिट टेस्ट 3 के परिणाम आ गए हैं! आपके वार्ड ने गणित में 78/100 अंक प्राप्त किए। रसायन पर ध्यान दें। — श्रीमती सुनीता',kn:'📊 ಘಟಕ ಪರೀಕ್ಷೆ 3 ಫಲಿತಾಂಶ! ನಿಮ್ಮ ಮಗು ಗಣಿತದಲ್ಲಿ 78/100 ಪಡೆದಿದ್ದಾರೆ. ರಸಾಯನ — AI ಯೋಜನೆ ಸಕ್ರಿಯ.',ta:'📊 அலகு தேர்வு 3 முடிவுகள்! கணிதத்தில் 78/100. வேதியியல் — AI திட்டம் செயலில்.',te:'📊 యూనిట్ టెస్ట్ 3 ఫలితాలు! గణితంలో 78/100. రసాయన — AI ప్లాన్ సక్రియం.'};
let previewVisible=false;
function updateSMSPreview(){if(previewVisible){const l=document.getElementById('sms-lang').value;document.getElementById('sms-preview-text').textContent=smsT[l]||smsT.en;}}
function togglePreview(){previewVisible=!previewVisible;const p=document.getElementById('sms-preview');if(previewVisible){p.style.display='block';updateSMSPreview();}else{p.style.display='none';}}
function sendSMS(){const sent=document.getElementById('sms-sent');sent.style.display='block';const l=document.getElementById('sms-lang').value;const names={en:'English',hi:'Hindi',kn:'Kannada',ta:'Tamil',te:'Telugu'};sent.textContent='✅ SMS sent to 32 parents in '+names[l]+' via Azure Communication Services!';setTimeout(()=>sent.style.display='none',5000);}
function aiDraftSMS(){document.getElementById('sms-msg').value='📚 Dear Parent, Unit Test 3 update: Your ward needs support in Chemistry. GURUKULAi AI study plan is now active. Please encourage daily study sessions at home. — Mrs. Sunitha, GURUKULAi';}
loadStudyMaterial(null,'Maths');
loadRandomQuiz();
</script>
</body>
</html>
# Out:
#   Cell In[1], line 6
#     <title>GURUKULAi — Smart Learning Platform</title>
#                      ^
# SyntaxError: invalid character '—' (U+2014)
